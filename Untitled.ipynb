# %%
from glob import glob
import numpy as np
import pandas as pd
import csv
import math
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier

# %%
#preP = "fmax9/train/*/"
#preP="oldCSVs/trainData-badChan/"
preP="bestData/train/"
files = glob(preP+'*.csv')
print(len(files))
trainCsv = pd.concat( [ pd.read_csv(f) for f in files ] )
combined_csv = trainCsv.query("label in ['absz', 'tcsz', 'tnsz', 'gnsz', 'cpsz', 'fnsz', 'spsz']")
#combined_csv = combined_csv[combined_csv.columns.drop(list(combined_csv.filter(regex='30-60Hz')))]
#combined_csv = combined_csv[combined_csv.columns.drop(list(combined_csv.filter(regex='60-90Hz')))]
# Out:
# 8

# %%
combined_csv.shape
# Out:
# (837, 2122)

# %%
files
# Out:
# ['bestData/train/allChtra0-0_B90_O0.5_W1.csv',
#  'bestData/train/allChtra0-6_B90_O0.5_W1.csv',
#  'bestData/train/allChtra0-1_B90_O0.5_W1.csv',
#  'bestData/train/allChtra1-3_B90_O0.5_W1.csv',
#  'bestData/train/allChtra0-3_B90_O0.5_W1.csv',
#  'bestData/train/allChtra1-4_B90_O0.5_W1.csv',
#  'bestData/train/allChtra0-2_B90_O0.5_W1.csv',
#  'bestData/train/allChtra0-5_B90_O0.5_W1.csv']

# %%
ar = trainCsv.loc[pd.isna(trainCsv["label"]), :].index

# %%
ar.shape[0]+837
# Out:
# 1216

# %%
#preP2 = "fmax90-notAllCha/test/*/"
#preP2="oldCSVs/testData-badChan/"
preP="bestData/test/"
files2 = glob(preP+'*.csv')

print(len(files2))
testCsv = pd.concat( [ pd.read_csv(f) for f in files2] )
combined_csv2 = testCsv.query("label in ['absz', 'tcsz', 'tnsz', 'gnsz', 'cpsz', 'fnsz', 'spsz']")
# Out:
# 4

# %%
combined_csv = pd.read_csv('finalTrainEmb.csv')
combined_csv2 = pd.read_csv('finalTestEmb.csv')

# %%
combined_csv = pd.read_csv('finalTrain.csv')
combined_csv2 = pd.read_csv('finalTest.csv')

# %%
trainCsv.shape
# Out:
# (1218, 2122)

# %%
combined_csv.to_csv("allNo3090.csv", index=False )
combined_csv2.to_csv("allEmbNo3060.csv", index=False )

# %%
dataset = np.array(combined_csv.values.tolist())
labels = dataset[:,-1]
xTrain = dataset[:,:-1]

trainScaler = MinMaxScaler(feature_range=(-1, 1))
trainScaler.fit(xTrain)

Ls = list(set(labels))
mappedLabels = [Ls.index(i) for i in list(labels)]
###################
#testset = np.array(combined_csv2.values.tolist())
#testLabels = testset[:,-1]
#xTest = testset[:,:-1]
#mappedTestLabels = [Ls.index(i) for i in list(testLabels)]


################

#xTrain = trainScaler.transform(xTrain)
#finalTestX = trainScaler.transform(xTest)

#X_train = xTrain
#Y_train = mappedLabels

#X_test = finalTestX
#Y_test = mappedTestLabels

# %%
list(set(Ls))
# Out:
# ['absz', 'spsz', 'cpsz', 'fnsz', 'gnsz', 'tnsz', 'tcsz']

# %%
[list(labels).count(i) for i in list(set(Ls))]
# Out:
# [99, 44, 251, 641, 467, 117, 68]

# %%
641+467
# Out:
# 1108

# %%
992+415
# Out:
# 1407

# %%
[Y_train.count(i) for i in list(set(Y_train))]
# Out:
# [385, 292, 50, 67, 183, 46, 41]

# %%
print(dataset.shape, testset.shape)
# Out:
# (837, 2122) (623, 2122)

# %%
def get_my_best_estimator(X, y, folds):

    params_grid = [{
        'C': [2**i for i in range(-9, 1)],
        #'gamma': [2**i for i in range(-6, 2)]
    }]
    gs = GridSearchCV(SVC(class_weight='balanced', kernel='linear'),
                      params_grid,
                      n_jobs=-1,
                      cv=folds)
    gs.fit(X, y)
    best_estimator = gs.best_estimator_
    return best_estimator








bestEstimator = get_my_best_estimator(X_train, Y_train, 5)
bestC = bestEstimator.C#2.0 #bestEstimator.C
bestGamma = bestEstimator.gamma #0.03125 #bestEstimator.gamma

modelRbf = SVC(C=bestC, kernel='linear', verbose=True, class_weight='balanced').fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e9802fc13fc1> in <module>
#      20
#      21
# ---> 22 bestEstimator = get_my_best_estimator(X_train, Y_train, 10)
#      23 bestC = bestEstimator.C#2.0 #bestEstimator.C
#      24 bestGamma = bestEstimator.gamma #0.03125 #bestEstimator.gamma
#
# <ipython-input-7-e9802fc13fc1> in get_my_best_estimator(X, y, folds)
#       9                       n_jobs=2,
#      10                       cv=folds)
# ---> 11     gs.fit(X, y)
#      12     best_estimator = gs.best_estimator_
#      13     return best_estimator
#
# /usr/local/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# /usr/local/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# /usr/local/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     538         AsyncResults.get from multiprocessing."""
#     539         try:
# --> 540             return future.result(timeout=timeout)
#     541         except CfTimeoutError:
#     542             raise TimeoutError()
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     428                 return self.__get_result()
#     429
# --> 430             self._condition.wait(timeout)
#     431
#     432             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/local/Cellar/python/3.7.7/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
bestC
# Out:
# 0.015625

# %%
predicted = modelRbf.predict(X_test)
f1_score(Y_test, predicted, average="weighted")
# Out:
# 0.5043003109923025

# %%
testset.shape
# Out:
# (657, 1920)

# %%
[2**i for i in range(-8, 1)]
# Out:
# [0.00390625, 0.0078125, 0.015625, 0.03125, 0.0625, 0.125, 0.25, 0.5, 1]

# %%
modelRbf = SVC(C=1.0,
               kernel='poly',
               
               decision_function_shape="ovr",
                class_weight='balanced',
               verbose=True).fit(X_train, Y_train)

predicted = modelRbf.predict(finalTestX)
f1_score(mappedTestLabels, predicted, average="weighted")

#scores = cross_val_score(modelRbf, X_train, Y_train, cv=5)
#np.mean(scores)
# Out:
# [LibSVM]
# 0.629798410755629

# %%
def get_my_best_estimator(X, y, folds):

    params_grid = [{
        'C': [2**i for i in range(-8, 4)],
        'gamma': [2**i for i in range(-6, 2)]}]
    gs = GridSearchCV(SVC(), params_grid, n_jobs=-1, cv=folds)
    gs.fit(X, y)
    best_estimator = gs.best_estimator_
    return best_estimator




bestEstimator = get_my_best_estimator(X_train, Y_train, 5)
bestC = bestEstimator.C#2.0 #bestEstimator.C
bestGamma = bestEstimator.gamma #0.03125 #bestEstimator.gamma

modelRbf = SVC(C=bestC , gamma=bestGamma, kernel='rbf', verbose=True, class_weight='balanced').fit(X_train, Y_train)
# Out:
# [LibSVM]

# %%
predicted = modelRbf.predict(finalTestX)
f1_score(mappedTestLabels, predicted, average="micro")
# Out:
# 0.4333868378812199

# %%
from sklearn.neighbors import KNeighborsClassifier
modelKNN = KNeighborsClassifier(n_neighbors=6).fit(X_train, Y_train)
predicted = modelKNN.predict(finalTestX)
f1_score(mappedTestLabels, predicted, average="weighted")
# Out:
# 0.5705163378768223

# %%
from sklearn.neighbors import KNeighborsClassifier
modelKNN = KNeighborsClassifier(n_neighbors=7).fit(X_train, Y_train)
predicted = modelKNN.predict(finalTestX)
f1_score(mappedTestLabels, predicted, average="weighted")
# Out:
# 0.6018627631701647

# %%
predicted = modelRbf.predict(finalTestX)
f1_score(mappedTestLabels, predicted, average="micro")
# Out:
# 0.5168539325842697

# %%
np.mean([0.5561797752808989, 0.8314606741573034])
# Out:
# 0.6938202247191012

# %%
DTC = DecisionTreeClassifier()

adaDTC = AdaBoostClassifier(DTC, random_state=7)

ada_param_grid = {"base_estimator__criterion" : ["gini", "entropy"],
              "base_estimator__splitter" :   ["best", "random"],
              "algorithm" : ["SAMME","SAMME.R"],
              "n_estimators" :[1,2],
              "learning_rate":  [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3,1.5]}

gsadaDTC = GridSearchCV(adaDTC,
                        param_grid = ada_param_grid, 
                        cv=10, 
                        scoring="f1_weighted", 
                        n_jobs=-1, 
                        verbose = 1)

gsadaDTC.fit(X_train,Y_train)

ada_best = gsadaDTC.best_estimator_

# %%
modelForest = ada_best.fit(X_train,Y_train)

scores = cross_val_score(modelForest, X_train, Y_train, cv=10)
np.mean(scores)

predicted = modelForest.predict(finalTestX)
f1_score(mappedTestLabels, predicted, average="weighted")
